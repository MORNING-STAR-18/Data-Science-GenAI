# %%
print("    morning star   ".strip())#remove space form both side
print("    morning star   ".lstrip())#remove space only form left side
print("    morning star   ".rstrip())#remove space only form right side
# Out:
# morning star
# morning star
#     morning star

# %%
name="  morning star    "

# %%
name=name.rstrip()
print(name)
# Out:
#   morning star

# %%
print("data">="data ")
# Out:
# False

# %%
id = 123
password = "morning star"

# %%
print(id == 100)
print(password == 'morning star')
# Out:
# False
# True

# %% [markdown]
# #### assignment

# %%
a = 2
print(a)
# Out:
# 2

# %%
a += 2

# %%
print(a)
# Out:
# 4

# %%
a /= 2
print(a)
# Out:
# 2.0

# %%
a *= 2
print(a)
# Out:
# 4.0

# %%
a -= 2
print(a)
# Out:
# 2.0
