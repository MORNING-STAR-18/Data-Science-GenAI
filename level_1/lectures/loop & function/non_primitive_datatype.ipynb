# %% [markdown]
# l = ["hello", "hey", 10, "morning star"]
# print(l)

# %%
print(l[1])
# Out:
# hey

# %%
print(l[-1])
print(l[len(l) - 1])
# Out:
# morning star
# morning star

# %%
len("data")
# Out:
# 4

# %%
l.pop(0)
# Out:
# 'hello'

# %%
print(l)
# Out:
# ['hey', 10, 'morning star']

# %%
l.insert(2, 1)

# %%
print(l)
# Out:
# ['hey', 10, 1, 'morning star']

# %%
reg = {
    "morning" : [10, 0, 8],
    "star" : [345,23434,"osdihfg"]
}

# %%
print(reg)
# Out:
# {'morning': [10, 0, 8], 'star': [345, 23434, 'osdihfg']}

# %%
print(reg["morning"])
# Out:
# [10, 0, 8]

# %%
reg.get("morning")
# Out:
# [10, 0, 8]

# %%
reg.get(100, "not found!")
# Out:
# 'not found!'

# %%
reg.keys()
# Out:
# dict_keys(['morning', 'star'])

# %%
reg.values()
# Out:
# dict_values([[10, 0, 8], [345, 23434, 'osdihfg']])

# %%
print(list(reg.keys()))
# Out:
# ['morning', 'star']

# %%
print(list(reg.values()))
# Out:
# [[10, 0, 8], [345, 23434, 'osdihfg']]

# %%
for i in list(reg.keys()):
    print(i)
# Out:
# morning
# star

# %%
for i in reg.keys():
    print(i)
# Out:
# morning
# star

# %%
for i in reg.values():
    print(i)
# Out:
# [10, 0, 8]
# [345, 23434, 'osdihfg']

# %%
dob = (10, 7, 2005)

# %%
print(dob)
print(type(dob))
# Out:
# (10, 7, 2005)
# <class 'tuple'>

# %%
print(dob[0])
# Out:
# 10

# %%
l_1 = [[1, 2, 3, 4], [5, 6, 7 ,8]]

# %%
print(l_1[1][0])
# Out:
# 5

# %% [markdown]
# reg_v1 = {
#     101 : {
#         "name" : {
#             "first_name" : "morning",
#             "last_name" : "star"
#         },
#         "dob" : (10, 7, 2005),
#         "phone no" : "111111111"
#     }
# }

# %%
print(reg_v1[101]["name"]["last_name"])
# Out:
# star

# %%
print(type(reg_v1[101]["name"]["last_name"]))
# Out:
# <class 'str'>

# %%
print(reg_v1.get(101).get("dob"))
# Out:
# (10, 7, 2005)

# %%
guests = {1, 1, 2, 3, "morning", "star", "star"}

# %%
print(guests)
# Out:
# {'morning', 1, 2, 3, 'star'}

# %%
type(guests)
# Out:
# set
