# %% [markdown]
# # String operations

# %%
name = "Monal S   "
# Out:
# Running cells with 'Python 3.14.7' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python -m pip install ipykernel -U --user --force-reinstall'

# %%
# strip()
name = name.strip() # it removes spaces from right and left side of the string
name

# %%
# rstrip()
name = "   Monal S   "
# print(name.rstrip())
name.rstrip()
# Out:
# Running cells with 'Python 3.14.7' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python -m pip install ipykernel -U --user --force-reinstall'

# %%
# lstrip()
name = "   Monal S   "
name.lstrip()

# %%
# remove space from both side without using strip()
name = "   Monal S   "
name = name.lstrip()
name = name.rstrip()
name

# %%
name = "   Monal S   "
name = name.lstrip().rstrip()
name

# %%
name = "   Monal S   "
name = name.rstrip().lstrip()
name

# %% [markdown]
# # Operators

# %% [markdown]
# #### Relational operators

# %%
a = 100
b = 200

# %%
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
print(a == b)
print(a != b)

# %%
a = "Data"
b = "Data "

print(a == b)

# %%
id_ = 123
password = "helloworld"

print(id_ == 100)
print(password == 'krishnaikacademy')

# %%
age_threshold = 18

person_1_age = 18

print(person_1_age >= age_threshold)

# %% [markdown]
# #### Assignment operator

# %%
a = 2
print(a)

# %%
a += 1 # a = a+1
print(a)

# %%
a -= 1 # a = a-1
print(a)

# %%
a *= 2 # a = a*2
print(a)

# %%
a /= 2 # a = a/2
print(a)

# %%
a / 0.3

# %%
a //= 0.3 # a = a//2
print(a)

# %% [markdown]
# # Logical Operators

# %%
bool_a = True
bool_b = False

# %%
bool_a and bool_b

# %%
bool_a or bool_b

# %%
not bool_b

# %%
not bool_a

# %%
# Club entry conditions
# - person should be over 18 or equal
# - person should have atleast 500 INR to enter in club

person_age = 20
person_threshold = 18

min_balance = 500
person_balance = 600

print((person_age >= person_threshold) and (person_balance >= min_balance))

# %% [markdown]
# #### bitwise operators

# %%
a = 3
b = 1

print(a & b)

# %%
print(a | b)

# %%
print(~a)

# %%
print(a ^ b)

# %%
a = 30
bin(a)

# %% [markdown]
# #### Conditional Statements or Control flow

# %%
# we want to give access to batch 1 recording to people who buy batch 2

current_batch = 3

if current_batch==2:
    print("Access to UDS batch 1.0 also provided")
else:
    print("You only have access to UDS batch 1.0")

# %%
# we want to give access to batch 1 recording to people who buy batch 2

current_batch = 3

if current_batch==2:
    print("Access to UDS batch 1.0 also provided")

a = 2
b = 2
print(a+b)

# %%
# we want to give access to batch 1 recording to people who buy batch 2

current_batch = 3

if current_batch == 2:
    print("hello")
else:
    print("Access to UDS batch 1.0 also provided")

a = 2
b = 2
print(a+b)

# %%
if True:
    print("hello")

# %% [markdown]
# #### if-elif-else

# %%
operation_name = "divide"

# contorl flow start
if operation_name == "add":
    print("Perform addition")
elif operation_name == "substract":
    print("Perform substraction")
elif operation_name == "divide":
    print("Perform division")
else:
    print("No selected operation name found.")
# contorl flow end

# %%
operation_name = "add"

# contorl flow start
if operation_name == "add":
    print("Perform addition")
# contorl flow end

# contorl flow start
if operation_name == "add":
    print("Perform addition")
elif operation_name == "substract":
    print("Perform substraction")
elif operation_name == "divide":
    print("Perform division")
else:
    print("No selected operation name found.")
# contorl flow end

# %%
age = 19
batch = 2.0
session_number = 4

# contorl flow start
if age > 19:
    print("19")
# contorl flow end

# contorl flow start
if batch >1.0:
    print("gives access to v1.0")
# contorl flow end

# contorl flow start
if session_number > 1:
    print("Induction class ended")
# contorl flow end

# %% [markdown]
# # More data types

# %%
id_people = [100, 101, 102, 103, 104, 105]

# %%
print(id_people)

# %%
people = [101, 100, 102, "A", "b", 37.4, True]

# %%
print(people)

# %%
print(type(people))

# %%
people.append("Data science")

# %%
print(people)

# %%
register = []
print(type(register))

# %%
# name = ""
# print(name)
# print(type(name))

# %%
register.append(["monal", 101, "+911234567890", "visit"])

# %%
# a = ["monal", 101, "+911234567890", "visit"]
# register.append(a)

# %%
print(register)

# %%
register.append(["pradeep", 101, "+911234567890", "visit"])

# %%
print(register)

# %% [markdown]
# ### experimentation on list

# %%
dummy = []

# %%
print(dummy)

# %%
dummy.append([1,2,3,4,"hello", "monal", 101]) 
# append is a method of list

# %%
len(dummy) # function
